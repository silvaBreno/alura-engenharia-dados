# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"52349707505","type":"IssueCommentEvent","actor":{"id":220355379,"login":"Benuben","display_login":"Benuben","gravatar_id":"","url":"https://api.github.com/users/Benuben","avatar_url":"https://avatars.githubusercontent.com/u/220355379?"},"repo":{"id":998165044,"name":"kimcartoon/mydic","url":"https://api.github.com/repos/kimcartoon/mydic"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/kimcartoon/mydic/issues/949","repository_url":"https://api.github.com/repos/kimcartoon/mydic","labels_url":"https://api.github.com/repos/kimcartoon/mydic/issues/949/labels{/name}","comments_url":"https://api.github.com/repos/kimcartoon/mydic/issues/949/comments","events_url":"https://api.github.com/repos/kimcartoon/mydic/issues/949/events","html_url":"https://github.com/kimcartoon/mydic/issues/949","id":3236496783,"node_id":"I_kwDOO37KNM7A6QWP","number":949,"title":"e240011","user":{"login":"utterances-bot","id":27942770,"node_id":"MDQ6VXNlcjI3OTQyNzcw","avatar_url":"https://avatars.githubusercontent.com/u/27942770?v=4","gravatar_id":"","url":"https://api.github.com/users/utterances-bot","html_url":"https://github.com/utterances-bot","followers_url":"https://api.github.com/users/utterances-bot/followers","following_url":"https://api.github.com/users/utterances-bot/following{/other_user}","gists_url":"https://api.github.com/users/utterances-bot/gists{/gist_id}","starred_url":"https://api.github.com/users/utterances-bot/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/utterances-bot/subscriptions","organizations_url":"https://api.github.com/users/utterances-bot/orgs","repos_url":"https://api.github.com/users/utterances-bot/repos","events_url":"https://api.github.com/users/utterances-bot/events{/privacy}","received_events_url":"https://api.github.com/users/utterances-bot/received_events","type":"User","user_view_type":"public","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":6,"created_at":"2025-07-16T15:53:51Z","updated_at":"2025-07-21T16:23:27Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"sub_issues_summary":{"total":0,"completed":0,"percent_completed":0},"body":"# Krypto: The Last Dog of Krypton Issue #2 - Read Krypto: The Last Dog of Krypton Issue #2 comic online in high quality\\n\\nRead Krypto: The Last Dog of Krypton Issue #2 comic online free and high quality. Unique reading type: All pages - just need to scroll to read next page.\\n\\n[https://readcomiconline.li/Comic/Krypto-The-Last-Dog-of-Krypton/Issue-2?id=240011](https://readcomiconline.li/Comic/Krypto-The-Last-Dog-of-Krypton/Issue-2?id=240011)","reactions":{"url":"https://api.github.com/repos/kimcartoon/mydic/issues/949/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"timeline_url":"https://api.github.com/repos/kimcartoon/mydic/issues/949/timeline","performed_via_github_app":null,"state_reason":null},"comment":{"url":"https://api.github.com/repos/kimcartoon/mydic/issues/comments/3097420234","html_url":"https://github.com/kimcartoon/mydic/issues/949#issuecomment-3097420234","issue_url":"https://api.github.com/repos/kimcartoon/mydic/issues/949","id":3097420234,"node_id":"IC_kwDOO37KNM64nuHK","user":{"login":"Benuben","id":220355379,"node_id":"U_kgDODSJbMw","avatar_url":"https://avatars.githubusercontent.com/u/220355379?v=4","gravatar_id":"","url":"https://api.github.com/users/Benuben","html_url":"https://github.com/Benuben","followers_url":"https://api.github.com/users/Benuben/followers","following_url":"https://api.github.com/users/Benuben/following{/other_user}","gists_url":"https://api.github.com/users/Benuben/gists{/gist_id}","starred_url":"https://api.github.com/users/Benuben/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Benuben/subscriptions","organizations_url":"https://api.github.com/users/Benuben/orgs","repos_url":"https://api.github.c ...

# %%
r.json()
# Out:
# [{'id': '52349707505',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 220355379,
#    'login': 'Benuben',
#    'display_login': 'Benuben',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Benuben',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/220355379?'},
#   'repo': {'id': 998165044,
#    'name': 'kimcartoon/mydic',
#    'url': 'https://api.github.com/repos/kimcartoon/mydic'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/kimcartoon/mydic/issues/949',
#     'repository_url': 'https://api.github.com/repos/kimcartoon/mydic',
#     'labels_url': 'https://api.github.com/repos/kimcartoon/mydic/issues/949/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kimcartoon/mydic/issues/949/comments',
#     'events_url': 'https://api.github.com/repos/kimcartoon/mydic/issues/949/events',
#     'html_url': 'https://github.com/kimcartoon/mydic/issues/949',
#     'id': 3236496783,
#     'node_id': 'I_kwDOO37KNM7A6QWP',
#     'number': 949,
#     'title': 'e240011',
#     'user': {'login': 'utterances-bot',
#      'id': 27942770,
#      'node_id': 'MDQ6VXNlcjI3OTQyNzcw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/27942770?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/utterances-bot',
#      'html_url': 'https://github.com/utterances-bot',
#      'followers_url': 'https://api.github.com/users/utterances-bot/followers',
#      'following_url': 'https://api.github.com/users/utterances-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/utterances-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/utterances-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/utterances-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/utterances-bot/orgs',
#      'repos_url': 'https://api.github.com/users/utterances-bot/repos',
#      'events_url': 'https://api.github.com/users/utterances-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/utterances-bot/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 6,
#     'created_at': '2025-07-16T15:53:51Z',
#     'updated_at': '2025-07-21T16:23:27Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'body': '# Krypto: The Last Dog of Krypton Issue #2 - Read Krypto: The Last Dog of Krypton Issue #2 comic online in high quality\n\nRead Krypto: The Last Dog of Krypton Issue #2 comic online free and high quality. Unique reading type: All pages - just need to scroll to read next page.\n\n[https://readcomiconline.li/Comic/Krypto-The-Last-Dog-of-Krypton/Issue-2?id=240011](https://readcomiconline.li/Comic/Krypto-The-Last-Dog-of-Krypton/Issue-2?id=240011)',
#     'reactions': {'url': 'https://api.github.com/repos/kimcartoon/mydic/issues/949/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/kimcartoon/mydic/issues/949/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/kimcartoon/mydic/issues/comments/3097420234',
#     'html_url': 'https://github.com/kimcartoon/mydic/issues/949#issuecomment-3097420234',
#     'issue_url': 'https://api.github.com/repos/kimcartoon/mydic/issues/949',
#     'id': 3097420234,
#     'node_id': 'IC_kwDOO37KNM64nuHK',
#     'user': {'login': 'Benuben',
#      'id': 220355379,
#      'node_id': 'U_kgDODSJbMw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/220355379?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Benuben',
#      'html_url': 'https://github.com/Benuben',
#      'followers_url': 'https://api.github.com/users/Benuben/followers',
#      'following_url': 'https://api.github.com/users/Benuben/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Benuben/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Benuben/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Benuben/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Benuben/orgs',
#      'repos_url': 'https://api.github.com/users/Benuben/repos',
#      'events_url': 'https://api.github.com/users/Benuben/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Benuben/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-07-21T16:23:27Z',
#     'updated_at': '2025-07-21T16:23:27Z',
#     'author_association': 'NONE',
#     'body': "Maybe it's just me, but having mini-Lex plan on murdering his extended family just to get their money when he's like 12 seems kinda... Silly? I think it's supposed to be based on him killing his dad, but that was cause his dad was abusive, it wasn't there just to show he was always a bad egg. It's kinda like revealing, because he froze his wife due to her illness, Mister Freeze actually has an entire fridge of girlfriends he froze after each an argument.",
#     'reactions': {'url': 'https://api.github.com/repos/kimcartoon/mydic/issues/comments/3097420234/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 7919,
#      'client_id': 'Iv1.a44a2bace9e1c9a9',
#      'slug': 'utterances',
#      'node_id': 'MDM6QXBwNzkxOQ==',
#      'owner': {'login': 'utterance',
#       'id': 27908738,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3OTA4NzM4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/27908738?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/utterance',
#       'html_url': 'https://github.com/utterance',
#       'followers_url': 'https://api.github.com/users/utterance/followers',
#       'following_url': 'https://api.github.com/users/utterance/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/utterance/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/utterance/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/utterance/subscriptions',
#       'organizations_url': 'https://api.github.com/users/utterance/orgs',
#       'repos_url': 'https://api.github.com/users/utterance/repos',
#       'events_url': 'https://api.github.com/users/utterance/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/utterance/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'name': 'utterances',
#      'description': 'A lightweight comments widget built on GitHub issues. Use GitHub issues for blog comments, wiki pages and more! Learn more at https://utteranc.es',
#      'external_url': 'https://utteranc.es',
#      'html_url': 'https://github.com/apps/utterances',
#      'created_at': '2018-01-05T13:59:15Z',
#      'updated_at': '2018-11-11T06:40:00Z',
#      'permissions': {'issues': 'write', 'metadata': 'read'},
#      'events': []}}},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707421',
#   'type': 'PushEvent',
#   'actor': {'id': 23044049,
#    'login': 'fengjun2016',
#    'display_login': 'fengjun2016',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fengjun2016',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23044049?'},
#   'repo': {'id': 908625963,
#    'name': 'fengjun2016/ollama',
#    'url': 'https://api.github.com/repos/fengjun2016/ollama'},
#   'payload': {'repository_id': 908625963,
#    'push_id': 25630427863,
#    'size': 425,
#    'distinct_size': 425,
#    'ref': 'refs/heads/main',
#    'head': '82da19c634b6cb2e72d6d648b278f1a1bfcc1e0c',
#    'before': '98272fbd58699366de72b5111d4f8fa79d9f71a4',
#    'commits': [{'sha': '25248f4bd5a1d720f6775ee1e45dfed718d6f98f',
#      'author': {'email': 'spamfaenger@gmx.de',
#       'name': '\u202erekcäH nitraM\u202e'},
#      'message': 'Better WantedBy declaration\n\nThe problem with default.target is that it always points to the target that is currently started. So if you boot into single user mode or the rescue mode still Ollama tries to start.\r\n\r\nI noticed this because either tried (and failed) to start all the time during a system update, where Ollama definitely is not wanted.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/25248f4bd5a1d720f6775ee1e45dfed718d6f98f'},
#     {'sha': '0daaaef8c99d94853eb12e897b2c15e0743a2575',
#      'author': {'email': 'jesse@ollama.com', 'name': 'Jesse Gross'},
#      'message': 'ollamarunner: Quiet debug logging and panic on unimplemented features\n\nDebug logging of every token has previously caused test timeouts\non slower machines.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/0daaaef8c99d94853eb12e897b2c15e0743a2575'},
#     {'sha': '6da8b6a87902c8cf875028329ade512c8d859059',
#      'author': {'email': 'jesse@ollama.com', 'name': 'Jesse Gross'},
#      'message': 'kvcache: Support non-causal attention\n\nModels can disable causality for all or part of their processing\nwhile continuing to store data in the KV cache.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/6da8b6a87902c8cf875028329ade512c8d859059'},
#     {'sha': '25f9b152f919b0262531873c935c301201d546aa',
#      'author': {'email': 'jesse@ollama.com', 'name': 'Jesse Gross'},
#      'message': 'ggml-backend: Ensure allocation meet backend requirements\n\nBackends can impose additional alignment requirements on buffer sizes.\nWe should ensure that we meet these or allocations can fail.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/25f9b152f919b0262531873c935c301201d546aa'},
#     {'sha': 'f52b2615ef3d82d4d95ce237233436f7cb818782',
#      'author': {'email': 'jesse@ollama.com', 'name': 'Jesse Gross'},
#      'message': 'kvcache: Set context for shift offsets',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/f52b2615ef3d82d4d95ce237233436f7cb818782'},
#     {'sha': '4100ed7bdd417ae6d25bf64467fb9df33f3f6525',
#      'author': {'email': 'jesse@ollama.com', 'name': 'Jesse Gross'},
#      'message': 'ml: Add support for quantized KV cache\n\nSimilar to the llama engine, quantizing the KV cache requires\nflash attention to be enabled through the Ollama server.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/4100ed7bdd417ae6d25bf64467fb9df33f3f6525'},
#     {'sha': '4614fafae0ee58af5b9d04ec4b8c2eb3846274da',
#      'author': {'email': 'jesse@ollama.com', 'name': 'Jesse Gross'},
#      'message': "ollamarunner: Don't panic for unimplemented features at runtime.\n\nIt's ok to fail on startup but we shouldn't panic during runtime\nbased on user input. Downgrade the panic to a warning.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/4614fafae0ee58af5b9d04ec4b8c2eb3846274da'},
#     {'sha': 'a1cda80bcb0b47d493be9dc061a2dfa8a0ddd61c',
#      'author': {'email': 'jesse@ollama.com', 'name': 'Jesse Gross'},
#      'message': "model: Update encoder cache to use multimodal input processing handler\n\nThe encoder cache needs to know the position of images in the input\nstream so that it knows when to delete them. Previously images didn't\nhave a position, so we implied one by breaking batches before an\nimage and then assuming the image was in the first position. However,\nmultimodal objects are now given explicit positions in the input\nstream, so we can use that instead.\n\nBreaking batches was also a way to simulate a cross attention mask\nfor mllama. However, given that it only supports a single sequence\nand a single image, this mask doesn't serve any real purpose.\nRemoving the batch break does not appear to affect the quality of\nthe output.\n\nMost of this is simply moving the input data structures to a new\npackage to avoid import cycles.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/a1cda80bcb0b47d493be9dc061a2dfa8a0ddd61c'},
#     {'sha': 'e093db92c4731b0cada767c7d5877c20d5f61dcf',
#      'author': {'email': 'jmorganca@gmail.com', 'name': 'Jeffrey Morgan'},
#      'message': 'sample: temporarily use grammars for constrained generation in new engine (#9586)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/e093db92c4731b0cada767c7d5877c20d5f61dcf'},
#     {'sha': '96ec8afd091a763762a75b57622759a1d278fa2c',
#      'author': {'email': 'sammcj@users.noreply.github.com', 'name': 'Sam'},
#      'message': 'docs(tool): add mcp-llm (#9537)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/96ec8afd091a763762a75b57622759a1d278fa2c'},
#     {'sha': '757668c42f92acf249677c9b3726bbfb2c1f5593',
#      'author': {'email': '33129495+zhu-xiaowei@users.noreply.github.com',
#       'name': 'Xiaowei Zhu'},
#      'message': 'docs: add SwiftChat (#9540)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/757668c42f92acf249677c9b3726bbfb2c1f5593'},
#     {'sha': 'd8a5d96b981bf6e1c5a61fde18acaeed0fb89f7c',
#      'author': {'email': 'rick+github@frob.com.au', 'name': 'frob'},
#      'message': 'docs: Add OLLAMA_CONTEXT_LENGTH to FAQ. (#9545)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/d8a5d96b981bf6e1c5a61fde18acaeed0fb89f7c'},
#     {'sha': 'fe776293f797ac0ac62e0b2a4f8997d8c9ffcf48',
#      'author': {'email': 'mxyng@pm.me', 'name': 'Michael Yang'},
#      'message': 'Merge pull request #9569 from dwt/patch-1\n\nBetter WantedBy declaration',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/fe776293f797ac0ac62e0b2a4f8997d8c9ffcf48'},
#     {'sha': '7e34f4fbfa192b3a2334d8fc28e24d69b83064d9',
#      'author': {'email': 'parth.sareen@ollama.com', 'name': 'Parth Sareen'},
#      'message': 'sample: add numerical stability to temperature/softmax transform (#9631)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/7e34f4fbfa192b3a2334d8fc28e24d69b83064d9'},
#     {'sha': '8585b7b151c404cc8044eeafe3734e676a0e572a',
#      'author': {'email': 'vincentkoc@ieee.org', 'name': 'Vincent Koc'},
#      'message': 'docs: add opik to observability integrations (#9626)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/8585b7b151c404cc8044eeafe3734e676a0e572a'},
#     {'sha': '9926eae01516fa3ab65d60df7dd0b51dceccdebf',
#      'author': {'email': 'mxyng@pm.me', 'name': 'Michael Yang'},
#      'message': 'fix: pad tensor item if ge zero\n\nthis produces a nicer output since both positive and negative values\nproduces the same width',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/9926eae01516fa3ab65d60df7dd0b51dceccdebf'},
#     {'sha': '26a26998fb24f1aaa1f0a95980050086d6cf64f0',
#      'author': {'email': 'mxyng@pm.me', 'name': 'Michael Yang'},
#      'message': 'Merge pull request #9590 from ollama/mxyng/dump-pad\n\nfix: pad tensor item if ge zero',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/26a26998fb24f1aaa1f0a95980050086d6cf64f0'},
#     {'sha': '4dcf80167aca16c90bd2d01e0b91473e595ae936',
#      'author': {'email': 'dhiltgen@users.noreply.github.com',
#       'name': 'Daniel Hiltgen'},
#      'message': 'Build release for windows with local script (#9636)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/4dcf80167aca16c90bd2d01e0b91473e595ae936'},
#     {'sha': '5f74d1fd47ec396ba40f60aee0a1a585ad0fcb4f',
#      'author': {'email': 'patrick@infrahq.com', 'name': 'Patrick Devine'},
#      'message': 'gemma2 impl',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/5f74d1fd47ec396ba40f60aee0a1a585ad0fcb4f'},
#     {'sha': '4b037a97dcc0387d2b94d293d4bd20e7e262d609',
#      'author': {'email': 'mxyng@pm.me', 'name': 'Michael Yang'},
#      'message': 'add gemma vision encoder',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fengjun2016/ollama/commits/4b037a97dcc0387d2b94d293d4bd20e7e262d609'}]},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707500',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 311511764,
#    'name': 'Mu-L/crowdsec',
#    'url': 'https://api.github.com/repos/Mu-L/crowdsec'},
#   'payload': {'action': 'opened',
#    'number': 30,
#    'pull_request': {'url': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/30',
#     'id': 2682479735,
#     'node_id': 'PR_kwDOEpFK1M6f42R3',
#     'html_url': 'https://github.com/Mu-L/crowdsec/pull/30',
#     'diff_url': 'https://github.com/Mu-L/crowdsec/pull/30.diff',
#     'patch_url': 'https://github.com/Mu-L/crowdsec/pull/30.patch',
#     'issue_url': 'https://api.github.com/repos/Mu-L/crowdsec/issues/30',
#     'number': 30,
#     'state': 'open',
#     'locked': False,
#     'title': '[pull] master from crowdsecurity:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'See Commits and Changes for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull) (v2.0.0-alpha.3)\n\n_Can you help keep this open source service alive? **[💖 Please sponsor : )](https://prod.download/pull-pr-sponsor)**_',
#     'created_at': '2025-07-21T16:23:27Z',
#     'updated_at': '2025-07-21T16:23:27Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '38613c733d0b4b06309d32c130a9bc23d3c5f43d',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/30/commits',
#     'review_comments_url': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/30/comments',
#     'review_comment_url': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Mu-L/crowdsec/issues/30/comments',
#     'statuses_url': 'https://api.github.com/repos/Mu-L/crowdsec/statuses/c7ff9211f0484aef04ff1b4a8ba7dfb421ce178f',
#     'head': {'label': 'crowdsecurity:master',
#      'ref': 'master',
#      'sha': 'c7ff9211f0484aef04ff1b4a8ba7dfb421ce178f',
#      'user': {'login': 'crowdsecurity',
#       'id': 63284097,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYzMjg0MDk3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/63284097?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/crowdsecurity',
#       'html_url': 'https://github.com/crowdsecurity',
#       'followers_url': 'https://api.github.com/users/crowdsecurity/followers',
#       'following_url': 'https://api.github.com/users/crowdsecurity/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/crowdsecurity/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/crowdsecurity/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/crowdsecurity/subscriptions',
#       'organizations_url': 'https://api.github.com/users/crowdsecurity/orgs',
#       'repos_url': 'https://api.github.com/users/crowdsecurity/repos',
#       'events_url': 'https://api.github.com/users/crowdsecurity/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/crowdsecurity/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 264154402,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjQxNTQ0MDI=',
#       'name': 'crowdsec',
#       'full_name': 'crowdsecurity/crowdsec',
#       'private': False,
#       'owner': {'login': 'crowdsecurity',
#        'id': 63284097,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYzMjg0MDk3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/63284097?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/crowdsecurity',
#        'html_url': 'https://github.com/crowdsecurity',
#        'followers_url': 'https://api.github.com/users/crowdsecurity/followers',
#        'following_url': 'https://api.github.com/users/crowdsecurity/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/crowdsecurity/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/crowdsecurity/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/crowdsecurity/subscriptions',
#        'organizations_url': 'https://api.github.com/users/crowdsecurity/orgs',
#        'repos_url': 'https://api.github.com/users/crowdsecurity/repos',
#        'events_url': 'https://api.github.com/users/crowdsecurity/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/crowdsecurity/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/crowdsecurity/crowdsec',
#       'description': 'CrowdSec - the open-source and participative security solution offering crowdsourced protection against malicious IPs and access to the most advanced real-world CTI.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/crowdsecurity/crowdsec',
#       'forks_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/forks',
#       'keys_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/teams',
#       'hooks_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/hooks',
#       'issue_events_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/events',
#       'assignees_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/tags',
#       'blobs_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/languages',
#       'stargazers_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/stargazers',
#       'contributors_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/contributors',
#       'subscribers_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/subscribers',
#       'subscription_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/subscription',
#       'commits_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/merges',
#       'archive_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/downloads',
#       'issues_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/crowdsecurity/crowdsec/deployments',
#       'created_at': '2020-05-15T09:38:05Z',
#       'updated_at': '2025-07-21T16:04:23Z',
#       'pushed_at': '2025-07-21T15:47:38Z',
#       'git_url': 'git://github.com/crowdsecurity/crowdsec.git',
#       'ssh_url': 'git@github.com:crowdsecurity/crowdsec.git',
#       'clone_url': 'https://github.com/crowdsecurity/crowdsec.git',
#       'svn_url': 'https://github.com/crowdsecurity/crowdsec',
#       'homepage': 'https://crowdsec.net',
#       'size': 168401,
#       'stargazers_count': 10701,
#       'watchers_count': 10701,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 519,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 225,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['attacks-prevention',
#        'detection',
#        'ids',
#        'ips',
#        'linux',
#        'protection',
#        'security',
#        'waf'],
#       'visibility': 'public',
#       'forks': 519,
#       'open_issues': 225,
#       'watchers': 10701,
#       'default_branch': 'master'}},
#     'base': {'label': 'Mu-L:master',
#      'ref': 'master',
#      'sha': '95a8b4750e4e578580084f2206f7bb0f04f08494',
#      'user': {'login': 'Mu-L',
#       'id': 18494722,
#       'node_id': 'MDQ6VXNlcjE4NDk0NzIy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/18494722?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Mu-L',
#       'html_url': 'https://github.com/Mu-L',
#       'followers_url': 'https://api.github.com/users/Mu-L/followers',
#       'following_url': 'https://api.github.com/users/Mu-L/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Mu-L/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Mu-L/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Mu-L/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Mu-L/orgs',
#       'repos_url': 'https://api.github.com/users/Mu-L/repos',
#       'events_url': 'https://api.github.com/users/Mu-L/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Mu-L/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 311511764,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTE1MTE3NjQ=',
#       'name': 'crowdsec',
#       'full_name': 'Mu-L/crowdsec',
#       'private': False,
#       'owner': {'login': 'Mu-L',
#        'id': 18494722,
#        'node_id': 'MDQ6VXNlcjE4NDk0NzIy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/18494722?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Mu-L',
#        'html_url': 'https://github.com/Mu-L',
#        'followers_url': 'https://api.github.com/users/Mu-L/followers',
#        'following_url': 'https://api.github.com/users/Mu-L/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Mu-L/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Mu-L/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Mu-L/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Mu-L/orgs',
#        'repos_url': 'https://api.github.com/users/Mu-L/repos',
#        'events_url': 'https://api.github.com/users/Mu-L/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Mu-L/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Mu-L/crowdsec',
#       'description': 'Crowdsec - An open-source, lightweight agent to detect and respond to bad behaviours. It also automatically benefits from our global community-wide IP reputation database.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Mu-L/crowdsec',
#       'forks_url': 'https://api.github.com/repos/Mu-L/crowdsec/forks',
#       'keys_url': 'https://api.github.com/repos/Mu-L/crowdsec/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Mu-L/crowdsec/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Mu-L/crowdsec/teams',
#       'hooks_url': 'https://api.github.com/repos/Mu-L/crowdsec/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Mu-L/crowdsec/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Mu-L/crowdsec/events',
#       'assignees_url': 'https://api.github.com/repos/Mu-L/crowdsec/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Mu-L/crowdsec/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Mu-L/crowdsec/tags',
#       'blobs_url': 'https://api.github.com/repos/Mu-L/crowdsec/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Mu-L/crowdsec/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Mu-L/crowdsec/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Mu-L/crowdsec/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Mu-L/crowdsec/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Mu-L/crowdsec/languages',
#       'stargazers_url': 'https://api.github.com/repos/Mu-L/crowdsec/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Mu-L/crowdsec/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Mu-L/crowdsec/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Mu-L/crowdsec/subscription',
#       'commits_url': 'https://api.github.com/repos/Mu-L/crowdsec/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Mu-L/crowdsec/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Mu-L/crowdsec/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Mu-L/crowdsec/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Mu-L/crowdsec/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Mu-L/crowdsec/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Mu-L/crowdsec/merges',
#       'archive_url': 'https://api.github.com/repos/Mu-L/crowdsec/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Mu-L/crowdsec/downloads',
#       'issues_url': 'https://api.github.com/repos/Mu-L/crowdsec/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Mu-L/crowdsec/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Mu-L/crowdsec/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Mu-L/crowdsec/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Mu-L/crowdsec/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Mu-L/crowdsec/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Mu-L/crowdsec/deployments',
#       'created_at': '2020-11-10T01:32:22Z',
#       'updated_at': '2025-07-18T16:23:35Z',
#       'pushed_at': '2025-07-18T16:23:31Z',
#       'git_url': 'git://github.com/Mu-L/crowdsec.git',
#       'ssh_url': 'git@github.com:Mu-L/crowdsec.git',
#       'clone_url': 'https://github.com/Mu-L/crowdsec.git',
#       'svn_url': 'https://github.com/Mu-L/crowdsec',
#       'homepage': 'https://crowdsec.net',
#       'size': 91164,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/30'},
#      'html': {'href': 'https://github.com/Mu-L/crowdsec/pull/30'},
#      'issue': {'href': 'https://api.github.com/repos/Mu-L/crowdsec/issues/30'},
#      'comments': {'href': 'https://api.github.com/repos/Mu-L/crowdsec/issues/30/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/30/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Mu-L/crowdsec/pulls/30/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Mu-L/crowdsec/statuses/c7ff9211f0484aef04ff1b4a8ba7dfb421ce178f'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 7,
#     'deletions': 10,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707483',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 32028077,
#    'login': 'zella1996',
#    'display_login': 'zella1996',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zella1996',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32028077?'},
#   'repo': {'id': 1011728383,
#    'name': 'oomol-lab/epub-translator',
#    'url': 'https://api.github.com/repos/oomol-lab/epub-translator'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/25',
#     'repository_url': 'https://api.github.com/repos/oomol-lab/epub-translator',
#     'labels_url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/25/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/25/comments',
#     'events_url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/25/events',
#     'html_url': 'https://github.com/oomol-lab/epub-translator/issues/25',
#     'id': 3244811894,
#     'node_id': 'I_kwDOPE2__87BZ-Z2',
#     'number': 25,
#     'title': '可能出现漏掉原文的情况，参考《猎青狮》的翻译情况',
#     'user': {'login': 'Moskize91',
#      'id': 14900772,
#      'node_id': 'MDQ6VXNlcjE0OTAwNzcy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/14900772?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Moskize91',
#      'html_url': 'https://github.com/Moskize91',
#      'followers_url': 'https://api.github.com/users/Moskize91/followers',
#      'following_url': 'https://api.github.com/users/Moskize91/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Moskize91/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Moskize91/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Moskize91/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Moskize91/orgs',
#      'repos_url': 'https://api.github.com/users/Moskize91/repos',
#      'events_url': 'https://api.github.com/users/Moskize91/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Moskize91/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'Moskize91',
#      'id': 14900772,
#      'node_id': 'MDQ6VXNlcjE0OTAwNzcy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/14900772?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Moskize91',
#      'html_url': 'https://github.com/Moskize91',
#      'followers_url': 'https://api.github.com/users/Moskize91/followers',
#      'following_url': 'https://api.github.com/users/Moskize91/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Moskize91/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Moskize91/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Moskize91/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Moskize91/orgs',
#      'repos_url': 'https://api.github.com/users/Moskize91/repos',
#      'events_url': 'https://api.github.com/users/Moskize91/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Moskize91/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'assignees': [{'login': 'Moskize91',
#       'id': 14900772,
#       'node_id': 'MDQ6VXNlcjE0OTAwNzcy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/14900772?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Moskize91',
#       'html_url': 'https://github.com/Moskize91',
#       'followers_url': 'https://api.github.com/users/Moskize91/followers',
#       'following_url': 'https://api.github.com/users/Moskize91/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Moskize91/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Moskize91/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Moskize91/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Moskize91/orgs',
#       'repos_url': 'https://api.github.com/users/Moskize91/repos',
#       'events_url': 'https://api.github.com/users/Moskize91/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Moskize91/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2025-07-19T03:06:17Z',
#     'updated_at': '2025-07-21T16:23:27Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'type': {'id': 20516913,
#      'node_id': 'IT_kwDOCLYhss4BORAx',
#      'name': 'Bug',
#      'description': 'An unexpected problem or behavior',
#      'color': 'red',
#      'created_at': '2024-02-19T19:16:54Z',
#      'updated_at': '2024-07-26T15:27:10Z',
#      'is_enabled': True},
#     'active_lock_reason': None,
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'body': '经调查，是第一步翻译就漏掉了部分原文，第二步对应补齐但无法修复。\n    - 可能措施 A：减少 tokens 的规模，看看能否缓解\n    - 可能措施 B：在第二部检查到缺失过多（遗漏行或某行tokens数相差太远）则触发矫正循环，直到修复。',
#     'reactions': {'url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/25/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/25/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/comments/3097420165',
#     'html_url': 'https://github.com/oomol-lab/epub-translator/issues/25#issuecomment-3097420165',
#     'issue_url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/25',
#     'id': 3097420165,
#     'node_id': 'IC_kwDOPE2__864nuGF',
#     'user': {'login': 'zella1996',
#      'id': 32028077,
#      'node_id': 'MDQ6VXNlcjMyMDI4MDc3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/32028077?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zella1996',
#      'html_url': 'https://github.com/zella1996',
#      'followers_url': 'https://api.github.com/users/zella1996/followers',
#      'following_url': 'https://api.github.com/users/zella1996/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zella1996/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zella1996/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zella1996/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zella1996/orgs',
#      'repos_url': 'https://api.github.com/users/zella1996/repos',
#      'events_url': 'https://api.github.com/users/zella1996/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zella1996/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-07-21T16:23:26Z',
#     'updated_at': '2025-07-21T16:23:26Z',
#     'author_association': 'NONE',
#     'body': '遇到类似问题，疑似响应的parser逻辑有bug，还没看里面的代码，llm是自建的deepseek14b，不确定是不是自身环境问题，仅作参考\n\n<img width="2760" height="1329" alt="Image" src="https://github.com/user-attachments/assets/5abacae5-14be-4da1-9bbf-f1747d9b8ff9" />',
#     'reactions': {'url': 'https://api.github.com/repos/oomol-lab/epub-translator/issues/comments/3097420165/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z',
#   'org': {'id': 146153906,
#    'login': 'oomol-lab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/oomol-lab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146153906?'}},
#  {'id': '52349707454',
#   'type': 'CreateEvent',
#   'actor': {'id': 14039341,
#    'login': 'joselcvarela',
#    'display_login': 'joselcvarela',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joselcvarela',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14039341?'},
#   'repo': {'id': 1023747002,
#    'name': 'joselcvarela/directus-extensions',
#    'url': 'https://api.github.com/repos/joselcvarela/directus-extensions'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707462',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 67609881,
#    'login': 'ellahathaway',
#    'display_login': 'ellahathaway',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ellahathaway',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67609881?'},
#   'repo': {'id': 65490742,
#    'name': 'dotnet/source-build',
#    'url': 'https://api.github.com/repos/dotnet/source-build'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/dotnet/source-build/issues/5286',
#     'repository_url': 'https://api.github.com/repos/dotnet/source-build',
#     'labels_url': 'https://api.github.com/repos/dotnet/source-build/issues/5286/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/dotnet/source-build/issues/5286/comments',
#     'events_url': 'https://api.github.com/repos/dotnet/source-build/issues/5286/events',
#     'html_url': 'https://github.com/dotnet/source-build/issues/5286',
#     'id': 3246498177,
#     'node_id': 'I_kwDOA-dPNs7BgaGB',
#     'number': 5286,
#     'title': 'Microsoft.Build.NoTargets missing in prep-source-build on 10.0.0-preview.6',
#     'user': {'login': 'corngood',
#      'id': 3077118,
#      'node_id': 'MDQ6VXNlcjMwNzcxMTg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3077118?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/corngood',
#      'html_url': 'https://github.com/corngood',
#      'followers_url': 'https://api.github.com/users/corngood/followers',
#      'following_url': 'https://api.github.com/users/corngood/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/corngood/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/corngood/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/corngood/subscriptions',
#      'organizations_url': 'https://api.github.com/users/corngood/orgs',
#      'repos_url': 'https://api.github.com/users/corngood/repos',
#      'events_url': 'https://api.github.com/users/corngood/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/corngood/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 2756001177,
#       'node_id': 'MDU6TGFiZWwyNzU2MDAxMTc3',
#       'url': 'https://api.github.com/repos/dotnet/source-build/labels/untriaged',
#       'name': 'untriaged',
#       'color': '006b75',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2025-07-20T16:36:30Z',
#     'updated_at': '2025-07-21T16:23:27Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'type': None,
#     'active_lock_reason': None,
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
# ...
#   'repo': {'id': 943468183,
#    'name': 'pipecat-ai/smart-turn',
#    'url': 'https://api.github.com/repos/pipecat-ai/smart-turn'},
#   'payload': {'repository_id': 943468183,
#    'push_id': 25630427793,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/khk/mps',
#    'head': '0fa8d5a1875e7b64ea969e66c6720a17c9830138',
#    'before': 'bb3679f08e4bbe79d89e3040161311211b7674f4',
#    'commits': [{'sha': '0fa8d5a1875e7b64ea969e66c6720a17c9830138',
#      'author': {'email': 'kwindla@daily.co', 'name': 'Kwindla Hultman Kramer'},
#      'message': 'small fix as per marcus',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pipecat-ai/smart-turn/commits/0fa8d5a1875e7b64ea969e66c6720a17c9830138'}]},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z',
#   'org': {'id': 169612734,
#    'login': 'pipecat-ai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pipecat-ai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/169612734?'}},
#  {'id': '52349707250',
#   'type': 'PushEvent',
#   'actor': {'id': 180045059,
#    'login': 'CYBORG-YASHRAJ',
#    'display_login': 'CYBORG-YASHRAJ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CYBORG-YASHRAJ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/180045059?'},
#   'repo': {'id': 1010794482,
#    'name': 'CYBORG-YASHRAJ/MAKERSPACE_KRMU',
#    'url': 'https://api.github.com/repos/CYBORG-YASHRAJ/MAKERSPACE_KRMU'},
#   'payload': {'repository_id': 1010794482,
#    'push_id': 25630427753,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '82b659be37ed83005f729e3133ad3b5b38c37c25',
#    'before': '9c0bf3d09c5bf9d6efdbc77bd9154dce3a254464',
#    'commits': [{'sha': '82b659be37ed83005f729e3133ad3b5b38c37c25',
#      'author': {'email': 'yashrajpahuja9999@gmail.com',
#       'name': 'Yashraj Pahuja'},
#      'message': 'MAKERSPACE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CYBORG-YASHRAJ/MAKERSPACE_KRMU/commits/82b659be37ed83005f729e3133ad3b5b38c37c25'}]},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707234',
#   'type': 'PushEvent',
#   'actor': {'id': 190502302,
#    'login': 'Ratna-Babu',
#    'display_login': 'Ratna-Babu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ratna-Babu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/190502302?'},
#   'repo': {'id': 1023731314,
#    'name': 'Ratna-Babu/Exoplanet-3d-model',
#    'url': 'https://api.github.com/repos/Ratna-Babu/Exoplanet-3d-model'},
#   'payload': {'repository_id': 1023731314,
#    'push_id': 25630427766,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a6b6013a6455291db29681d34a84872814810c3f',
#    'before': '61797caa53c6b9405697bfb601d6b14abf320ada',
#    'commits': [{'sha': 'a6b6013a6455291db29681d34a84872814810c3f',
#      'author': {'email': 'ratna71babu@gmail.com',
#       'name': 'Bantupalli Ratna Babu'},
#      'message': 'Create requirements.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ratna-Babu/Exoplanet-3d-model/commits/a6b6013a6455291db29681d34a84872814810c3f'}]},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707224',
#   'type': 'PushEvent',
#   'actor': {'id': 128402149,
#    'login': 'hemanth0525',
#    'display_login': 'hemanth0525',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hemanth0525',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128402149?'},
#   'repo': {'id': 1010761869,
#    'name': 'hemanth0525/cloud9.recipes',
#    'url': 'https://api.github.com/repos/hemanth0525/cloud9.recipes'},
#   'payload': {'repository_id': 1010761869,
#    'push_id': 25630427817,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '27a88d034a1a5e304c7e64e4ef3a0c873365314b',
#    'before': 'de8991010027955f645214b70b7a99d54ee3360f',
#    'commits': [{'sha': '27a88d034a1a5e304c7e64e4ef3a0c873365314b',
#      'author': {'email': '128402149+hemanth0525@users.noreply.github.com',
#       'name': 'HEMANTH M'},
#      'message': 'Add image2 image for Homemade Tangy French Dressing',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hemanth0525/cloud9.recipes/commits/27a88d034a1a5e304c7e64e4ef3a0c873365314b'}]},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707242',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 5370137,
#    'login': 'katsmith133',
#    'display_login': 'katsmith133',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/katsmith133',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5370137?'},
#   'repo': {'id': 602658300,
#    'name': 'E3SM-Project/Omega',
#    'url': 'https://api.github.com/repos/E3SM-Project/Omega'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/222',
#     'repository_url': 'https://api.github.com/repos/E3SM-Project/Omega',
#     'labels_url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/222/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/222/comments',
#     'events_url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/222/events',
#     'html_url': 'https://github.com/E3SM-Project/Omega/pull/222',
#     'id': 3005531738,
#     'node_id': 'PR_kwDOI-vV_M6TJyiD',
#     'number': 222,
#     'title': 'add eos to omega',
#     'user': {'login': 'alicebarthel',
#      'id': 36741014,
#      'node_id': 'MDQ6VXNlcjM2NzQxMDE0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/36741014?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alicebarthel',
#      'html_url': 'https://github.com/alicebarthel',
#      'followers_url': 'https://api.github.com/users/alicebarthel/followers',
#      'following_url': 'https://api.github.com/users/alicebarthel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alicebarthel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alicebarthel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alicebarthel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alicebarthel/orgs',
#      'repos_url': 'https://api.github.com/users/alicebarthel/repos',
#      'events_url': 'https://api.github.com/users/alicebarthel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alicebarthel/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 5163221169,
#       'node_id': 'LA_kwDOI-vV_M8AAAABM8CAsQ',
#       'url': 'https://api.github.com/repos/E3SM-Project/Omega/labels/enhancement',
#       'name': 'enhancement',
#       'color': 'a2eeef',
#       'default': True,
#       'description': 'New feature or request'},
#      {'id': 5306104611,
#       'node_id': 'LA_kwDOI-vV_M8AAAABPES7Iw',
#       'url': 'https://api.github.com/repos/E3SM-Project/Omega/labels/Omega',
#       'name': 'Omega',
#       'color': '0FBB88',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 36,
#     'created_at': '2025-04-18T18:36:02Z',
#     'updated_at': '2025-07-21T16:23:26Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'type': None,
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/E3SM-Project/Omega/pulls/222',
#      'html_url': 'https://github.com/E3SM-Project/Omega/pull/222',
#      'diff_url': 'https://github.com/E3SM-Project/Omega/pull/222.diff',
#      'patch_url': 'https://github.com/E3SM-Project/Omega/pull/222.patch',
#      'merged_at': None},
#     'body': "This PR adds the Eos class to the omega code. \r\nIt includes methods to calculate the specific volume using either a linear Eos option, or the TEOS-10 eos (implemented by the 75-term polynomial from Roquet et al 2015) from the model state T,S,P. The Eos option (and parameters if needed) are set in the yaml config file. The TEOS-10 option includes a method to calculate the specific volume displaced to the layer below. \r\nIt includes a full-array test on the expected values of specific volume calculated with either Eos.\r\nAt this stage, I removed the single-value tests that were used for development but are not set up to work on GPUs (they recently passed on CPUs). I can remove them entirely or adapt them depending on reviews. \r\n\r\nChrysalis: passes all Ctests with intel and gnu\r\nPerlmutter: passes all Ctests on gpu (`Debug` or `Release` flags, see comment below) \r\n\r\nChecklist\r\n* [x] Documentation:\r\n  * [x] Design document has been generated and added to the docs (done in @sbrus89's PR)\r\n  * [x] User's Guide has been updated\r\n  * [x] Developer's Guide has been updated\r\n  * [x] Documentation has been [built locally](https://e3sm-project.github.io/Omega/omega/develop/devGuide/BuildDocs.html) and changes look as expected\r\n* [x] Testing\r\n  * [x] A comment in the PR documents testing used to verify the changes including any tests that are added/modified/impacted.\r\n  * [x] CTest unit tests for new features have been added per the approved design. \r\n  * [x] Polaris tests for new features have been added per the approved design (and included in a test suite)\r\n  * [x] Unit tests have passed. Please provide a relevant CDash build entry for verification.\r\n  * [ ] Polaris test suite has passed\r\n  * [ ] Performance related PRs: Please include a relevant PACE experiment link documenting performance before and after.\r\n",
#     'reactions': {'url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/222/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/222/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/comments/3097420039',
#     'html_url': 'https://github.com/E3SM-Project/Omega/pull/222#issuecomment-3097420039',
#     'issue_url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/222',
#     'id': 3097420039,
#     'node_id': 'IC_kwDOI-vV_M64nuEH',
#     'user': {'login': 'katsmith133',
#      'id': 5370137,
#      'node_id': 'MDQ6VXNlcjUzNzAxMzc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5370137?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/katsmith133',
#      'html_url': 'https://github.com/katsmith133',
#      'followers_url': 'https://api.github.com/users/katsmith133/followers',
#      'following_url': 'https://api.github.com/users/katsmith133/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/katsmith133/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/katsmith133/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/katsmith133/subscriptions',
#      'organizations_url': 'https://api.github.com/users/katsmith133/orgs',
#      'repos_url': 'https://api.github.com/users/katsmith133/repos',
#      'events_url': 'https://api.github.com/users/katsmith133/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/katsmith133/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-07-21T16:23:26Z',
#     'updated_at': '2025-07-21T16:23:26Z',
#     'author_association': 'NONE',
#     'body': '> @katsmith133\r\n> \r\n> It seems like the linear eos.parameters are not set by `Eos::init()` when the config file uses `EosType: teos10`, but the linear eos is still being tested. That might be the issue.\r\n\r\nYup! Thanks, @mwarusz, I just came to that same conclusion myself. I think setting them in the LinearEos class, so that at least the values are there even if they are not set by `Eos::init()` is the best solution. I am running the tests to make sure that all works, but I think that might be the fix.',
#     'reactions': {'url': 'https://api.github.com/repos/E3SM-Project/Omega/issues/comments/3097420039/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z',
#   'org': {'id': 7558558,
#    'login': 'E3SM-Project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/E3SM-Project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7558558?'}},
#  {'id': '52349707246',
#   'type': 'PushEvent',
#   'actor': {'id': 56641652,
#    'login': 'mario-97',
#    'display_login': 'mario-97',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mario-97',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56641652?'},
#   'repo': {'id': 1019840114,
#    'name': 'mario-97/proyecto-cripto-data',
#    'url': 'https://api.github.com/repos/mario-97/proyecto-cripto-data'},
#   'payload': {'repository_id': 1019840114,
#    'push_id': 25630427785,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a20737d574c740a01ddd13977b8b855bffcd5b72',
#    'before': '0eb3daa5b8fbc16d299da4e1abd5b027e8203401',
#    'commits': [{'sha': 'a20737d574c740a01ddd13977b8b855bffcd5b72',
#      'author': {'email': '56641652+mario-97@users.noreply.github.com',
#       'name': 'Mario Ulloa O'},
#      'message': 'Upload logs_actualizacion.csv',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mario-97/proyecto-cripto-data/commits/a20737d574c740a01ddd13977b8b855bffcd5b72'}]},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'},
#  {'id': '52349707249',
#   'type': 'PushEvent',
#   'actor': {'id': 156710758,
#    'login': 'gov4git-bot',
#    'display_login': 'gov4git-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gov4git-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156710758?'},
#   'repo': {'id': 836014407,
#    'name': 'gov4git/sample-project-2-gov.public',
#    'url': 'https://api.github.com/repos/gov4git/sample-project-2-gov.public'},
#   'payload': {'repository_id': 836014407,
#    'push_id': 25630427796,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main.cron',
#    'head': '35f2139e85a49e608c193b93b765bdef9aaf4224',
#    'before': 'fb03f1b405b9d4c6ffc7550a6d1cbb7a7e888276',
#    'commits': [{'sha': '35f2139e85a49e608c193b93b765bdef9aaf4224',
#      'author': {'email': 'no-reply@gov4git', 'name': 'gov4git governance'},
#      'message': 'Gov4Git dev cron job.\n\n{\n   "msg": "Gov4Git dev cron job.",\n   "fn": "cron",\n   "query": null,\n   "result": {\n      "change_stamp": "2025-07-21T16:22:35.456797885Z",\n      "gov4git_version": {\n         "version": "dev",\n         "revision": "9d680797696ac662a9515f1e33272ccdf55848c7",\n         "last_commit": "2024-05-19T05:57:47Z",\n         "dirty_build": false\n      }\n   },\n   "steps": null\n}',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gov4git/sample-project-2-gov.public/commits/35f2139e85a49e608c193b93b765bdef9aaf4224'}]},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z',
#   'org': {'id': 115105173,
#    'login': 'gov4git',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gov4git',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115105173?'}},
#  {'id': '52349707235',
#   'type': 'CreateEvent',
#   'actor': {'id': 26017734,
#    'login': 'automationhacks',
#    'display_login': 'automationhacks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/automationhacks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26017734?'},
#   'repo': {'id': 1023748388,
#    'name': 'automationhacks/azure_devops_kit',
#    'url': 'https://api.github.com/repos/automationhacks/azure_devops_kit'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-21T16:23:28Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
r = requests.get('https://api.github.com/users/silvaBreno')
r.status_code
# Out:
# 200

# %%
print('='*48 + f"\nNome: {r.json()['name']}\nNome do Usuário: {r.json()['login']}\nNúmero de repositórios públicos: {r.json()['public_repos']}\nData de criação da conta: {r.json()['created_at']}\n" + '='*48)
# Out:
# ================================================
# Nome: Breno Silva
# Nome do Usuário: silvaBreno
# Número de repositórios públicos: 13
# Data de criação da conta: 2022-01-24T21:43:05Z
# ================================================

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2025-07-16T22:32:21Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 398,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 398,
#   'open_issues': 3,
#   'watchers': 18,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2025-07-17T21:43:10Z',
#   'pushed_at': '2025-03-25T21:20:38Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 719,
#   'stargazers_count': 120,
#   'watchers_count': 120,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 41,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 29,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 41,
#   'open_issues': 29,
#   'watchers': 120,
#   'default_branch': 'main'},
#  {'id': 958141729,
#   'node_id': 'R_kgDOORwVIQ',
#   'name': 'ads-pao-amznjs-gtm-server-side-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-server-side-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-server-side-template/deployments',
#   'created_at': '2025-03-31T17:58:12Z',
#   'updated_at': '2025-07-12T06:55:54Z',
#   'pushed_at': '2025-05-12T16:20:28Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-server-side-template',
#   'homepage': None,
#   'size': 69,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 1,
#   'watchers': 1,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-09-05T08:32:25Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2025-06-10T17:04:15Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1137,
#   'watchers_count': 1137,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1032,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1032,
#   'open_issues': 11,
#   'watchers': 1137,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2025-06-06T14:28:27Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 11,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
# ...
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-api-sdk-ruby/deployments',
#   'created_at': '2024-07-31T06:15:43Z',
#   'updated_at': '2025-05-29T10:28:14Z',
#   'pushed_at': '2025-05-29T10:28:42Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-api-sdk-ruby.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-api-sdk-ruby',
#   'homepage': None,
#   'size': 52,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'main'},
#  {'id': 33279165,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzI3OTE2NQ==',
#   'name': 'amazon-pay-code-samples',
#   'full_name': 'amzn/amazon-pay-code-samples',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-code-samples',
#   'description': 'Amazon Pay SDK Sample Code',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-code-samples/deployments',
#   'created_at': '2015-04-01T23:52:35Z',
#   'updated_at': '2025-05-26T08:41:56Z',
#   'pushed_at': '2023-04-10T09:51:00Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-code-samples.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-code-samples.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-code-samples.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-code-samples',
#   'homepage': '',
#   'size': 4573,
#   'stargazers_count': 43,
#   'watchers_count': 43,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 10,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 10,
#   'watchers': 43,
#   'default_branch': 'master'},
#  {'id': 27617078,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYxNzA3OA==',
#   'name': 'amazon-pay-sdk-csharp',
#   'full_name': 'amzn/amazon-pay-sdk-csharp',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'description': 'Amazon Pay C# SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2025-06-22T21:57:29Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 40,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 40,
#   'open_issues': 11,
#   'watchers': 48,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %% [markdown]
# ### Paginando os repositórios

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %% [markdown]
# ### Linguagens dos repositórios

# %% [markdown]
# ### Criando um DataFrame

# %% [markdown]
# Salvando o DataFrame

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %% [markdown]
# ### Formato do arquivo

# %% [markdown]
# ### Upload de arquivo com PUT
